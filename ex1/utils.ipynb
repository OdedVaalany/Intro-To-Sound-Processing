# %%
from digit_classifier import *
import matplotlib.pyplot as plt
import torch

# audio_check_fft_stft()
self_check_fft_stft()
# Out:
# torch.Size([1, 48000])
# torch.Size([1, 48000])
# torch.Size([1, 48000])

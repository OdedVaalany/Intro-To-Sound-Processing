# %%
import digit_classifier as dc

from torch.nn.functional import pad
if __name__ == "__main__":
    dc.self_check_fft_stft()
    dc.audio_check_fft_stft()
    # all_digits = [pad(ta.load(f"./audio_files/phone_digits_8k/phone_{i}.wav")[0],(0,400)) for i in range(12)]
    # all_digits = [pad(ta.load(f"./audio_files/phone_digits_8k/phone_{i}.wav")[0],(0,400)) for i in range(0,12,2)]
    # all_digits = [pad(ta.load(f"./audio_files/phone_digits_8k/phone_{i}.wav")[0],(0,400)) for i in range(1,12,2)]
    all_digits = [pad(ta.load(f"./audio_files/phone_digits_8k/phone_{i}.wav")[0],(0,400)) for i in range(0,12,3)]
    all_digits = torch.cat(all_digits,dim=-1)
    print(classify_digit_stream(all_digits))
# Out:
# torch.Size([3, 1, 2880000])
# True torch.Size([25, 1, 800, 1, 2])
# 3
# [0, 3, 6, 9]
